# %% [raw]
# # Jet Tagging with Boosting Decision Trees (BDT)
#
# This notebook shows how to use XGBoost for jet classification between QCD and TT jets using particle-level features.
#
# ## What is XGBoost?
# XGBoost (eXtreme Gradient Boosting) is a package for gradient boosted decision trees designed for speed and performance. It can handle large datasets and is perhaps the most used Python BDT implementation.
#
# ## Why use BDTs for Jet Tagging?
# - Quick to train
# - More explainable than most other ML alternatives
# - Less prone to overfitting compared to deep learning methods
# - Despite being simple, BDTs often achieve good performance on complex tasks

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
from jet_util import load_processed_data 
from jet_plotting_util import plot_confusion_matrix, plot_roc_curve

# %% [markdown]
# ## 1. Load and Prepare Data
#
# We'll use particle-level features from the jet data. See kaggle for a detailed description of the data.

# %%
# Load data
# Create feature matrix and labels

X_train, y_train, train_ids, X_val, y_val, val_ids, X_test, test_ids= load_processed_data()

X_train.shape
# Out:
# (3520, 14)

# %%
X_train.head()
# Out:
#    n_clusters  max_cluster_pt  mean_cluster_pt  std_cluster_pt  \
# 0          13             2.0         0.615318        0.539951
# 1          10             2.0         0.777020        0.601157
# 2           4             2.0         0.972718        0.606990
# 3          14             2.0         0.746367        0.485636
# 4           6             2.0         0.575760        0.639069
#
#    max_cluster_size  mean_cluster_size  std_cluster_size   total_pt  \
# 0                 2                2.0               0.0   7.999129
# 1                 2                2.0               0.0   7.770204
# 2                 2                2.0               0.0   3.890871
# 3                 2                2.0               0.0  10.449135
# 4                 2                2.0               0.0   3.454561
#
#    max_cluster_eta  max_cluster_phi  mean_cluster_eta  mean_cluster_phi  \
# 0              0.5              0.7          0.076923          0.346154
# 1              0.2              0.5          0.100000          0.230000
# 2              0.1              0.1          0.050000          0.050000
# 3              0.5              0.5          0.185714          0.285714
# 4              0.1              0.1          0.050000          0.066667
#
#    cluster_pt_ratio  cluster_size_ratio
# 0          1.470200                 1.0
# 1          1.430785                 1.0
# 2          2.557882                 1.0
# 3          1.624096                 1.0
# 4          4.988196                 1.0

# %% [markdown]
# ## 2. Train XGBoost Model
#
# XGBoost has several important hyperparameters:
# - `n_estimators`: How many trees to we use
# - `max_depth`: How deep is each tree - i.e. how many decisions does it make. Can you see a reason why we might want to set a max here?
# - `learning_rate`: How big is our gradient step
# - `objective`: Learning task and objective function - since we can do classification or regression it's important to select the right one here.

# %%
# Initialize and train model
model = xgb.XGBClassifier(
    n_estimators=100,  # Number of boosting rounds
    max_depth=5,      # Maximum tree depth
    learning_rate=0.1, # Step size shrinkage
    objective='binary:logistic',  # Binary classification
    random_state=42
)

# Train the model
model.fit(X_train, y_train,
          eval_set=[(X_val, y_val)],
          verbose=True)
# Out:
# [0]	validation_0-logloss:0.57961
# [1]	validation_0-logloss:0.53210
# [2]	validation_0-logloss:0.49289
# [3]	validation_0-logloss:0.46156
# [4]	validation_0-logloss:0.43472
# [5]	validation_0-logloss:0.41170
# [6]	validation_0-logloss:0.39103
# [7]	validation_0-logloss:0.37475
# [8]	validation_0-logloss:0.35926
# [9]	validation_0-logloss:0.34601
# [10]	validation_0-logloss:0.33491
# [11]	validation_0-logloss:0.32556
# [12]	validation_0-logloss:0.31714
# [13]	validation_0-logloss:0.31017
# [14]	validation_0-logloss:0.30415
# [15]	validation_0-logloss:0.29847
# [16]	validation_0-logloss:0.29437
# [17]	validation_0-logloss:0.28939
# [18]	validation_0-logloss:0.28581
# [19]	validation_0-logloss:0.28159
# [20]	validation_0-logloss:0.27922
# [21]	validation_0-logloss:0.27734
# [22]	validation_0-logloss:0.27467
# [23]	validation_0-logloss:0.27243
# [24]	validation_0-logloss:0.27074
# [25]	validation_0-logloss:0.26919
# [26]	validation_0-logloss:0.26816
# [27]	validation_0-logloss:0.26673
# [28]	validation_0-logloss:0.26597
# [29]	validation_0-logloss:0.26509
# [30]	validation_0-logloss:0.26453
# [31]	validation_0-logloss:0.26373
# [32]	validation_0-logloss:0.26325
# [33]	validation_0-logloss:0.26241
# [34]	validation_0-logloss:0.26156
# [35]	validation_0-logloss:0.26167
# [36]	validation_0-logloss:0.26148
# [37]	validation_0-logloss:0.26101
# [38]	validation_0-logloss:0.26103
# [39]	validation_0-logloss:0.26116
# [40]	validation_0-logloss:0.26084
# [41]	validation_0-logloss:0.26066
# [42]	validation_0-logloss:0.26040
# [43]	validation_0-logloss:0.26006
# [44]	validation_0-logloss:0.26029
# [45]	validation_0-logloss:0.26083
# [46]	validation_0-logloss:0.26052
# [47]	validation_0-logloss:0.26110
# [48]	validation_0-logloss:0.26134
# [49]	validation_0-logloss:0.26104
# [50]	validation_0-logloss:0.26114
# [51]	validation_0-logloss:0.26169
# [52]	validation_0-logloss:0.26276
# [53]	validation_0-logloss:0.26251
# [54]	validation_0-logloss:0.26261
# [55]	validation_0-logloss:0.26310
# [56]	validation_0-logloss:0.26295
# [57]	validation_0-logloss:0.26290
# [58]	validation_0-logloss:0.26294
# [59]	validation_0-logloss:0.26311
# [60]	validation_0-logloss:0.26362
# [61]	validation_0-logloss:0.26271
# [62]	validation_0-logloss:0.26306
# [63]	validation_0-logloss:0.26313
# [64]	validation_0-logloss:0.26268
# [65]	validation_0-logloss:0.26380
# [66]	validation_0-logloss:0.26371
# [67]	validation_0-logloss:0.26375
# [68]	validation_0-logloss:0.26414
# [69]	validation_0-logloss:0.26413
# [70]	validation_0-logloss:0.26412
# [71]	validation_0-logloss:0.26456
# [72]	validation_0-logloss:0.26465
# [73]	validation_0-logloss:0.26477
# [74]	validation_0-logloss:0.26521
# [75]	validation_0-logloss:0.26573
# [76]	validation_0-logloss:0.26584
# [77]	validation_0-logloss:0.26589
# [78]	validation_0-logloss:0.26604
# [79]	validation_0-logloss:0.26619
# [80]	validation_0-logloss:0.26583
# [81]	validation_0-logloss:0.26607
# [82]	validation_0-logloss:0.26743
# [83]	validation_0-logloss:0.26730
# [84]	validation_0-logloss:0.26791
# [85]	validation_0-logloss:0.26798
# [86]	validation_0-logloss:0.26782
# [87]	validation_0-logloss:0.26801
# [88]	validation_0-logloss:0.26834
# [89]	validation_0-logloss:0.26854
# [90]	validation_0-logloss:0.26867
# [91]	validation_0-logloss:0.26904
# [92]	validation_0-logloss:0.26920
# [93]	validation_0-logloss:0.26941
# [94]	validation_0-logloss:0.27026
# [95]	validation_0-logloss:0.27027
# [96]	validation_0-logloss:0.27047
# [97]	validation_0-logloss:0.27072
# [98]	validation_0-logloss:0.27167
# [99]	validation_0-logloss:0.27174
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# ## 3. Evaluate Model
#
# Let's evaluate our model using:
# - Accuracy: Overall prediction accuracy
# - Confusion Matrix: This is common for classifications. How often did we classify or misclassify each category? It's common that some categories are harder than others.

# %%
# Make predictions

# this gives us probabilities for both categories - we only want for ttbar, so we select one column
# with a binary classification, the probability for one category implies the other 
y_pred = model.predict_proba(X_val)[:, 1]

# to test accuracy and confusion matrix, we need labels 0 and 1, so we set that based on a threshold
discrete_pred = np.where(y_pred > 0.5, 1, 0)
# Calculate accuracy
accuracy = accuracy_score(y_val, np.where(y_pred > 0.5, 1, 0))
print(f"Test Accuracy: {accuracy:.4f}")

# Plot confusion matrix
plot_confusion_matrix(y_val, discrete_pred)
# Out:
# Test Accuracy: 0.8785

# %%
plot_roc_curve(y_val, y_pred)

# %% [markdown]
# ## 4. Feature Importance Analysis
#
# One of the advantages of BDTs is that they provide feature importance scores, which help us understand which features are most important for the classification task. Beware that this doesn't translate directly to which are the best features in the data - only to what the model thinks. So if you have a bad model, your feature importance will be equally useless. Another model could also pick up on features that the BDT didn't, so it's only an indicator.

# %%
# Plot feature importance
importance = model.feature_importances_
feature_importance = pd.DataFrame({
    'feature': X_train.columns,
    'importance': importance
}).sort_values('importance', ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x='importance', y='feature', data=feature_importance)
plt.title('Feature Importance')
plt.tight_layout() 
plt.show()

# %% [markdown]
# # 5 - Make kaggle predictions¶

# %%
# test_predictions = model.predict_proba(X_test)[:, 1]
# solution = pd.DataFrame({'id':test_ids, 'label':test_predictions})
# solution.to_csv('solutions.csv', index=False)
